# %%
# Carico il dataset in un DataFrame
import pandas as pd

covid_data = pd.read_csv("owid-covid-data.csv")

# %%
# Verifica dimensioni del datset 
print("Dimensioni del dataset:")
print(covid_data.shape)
# Out:
# Dimensioni del dataset:
# (387330, 67)

# %%
# Visualizzazione delle prime 5 righe del dataset per capire la struttura
print("Prime cinque righe del dataset:")
covid_data.head()
# Out:
# Prime cinque righe del dataset:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
# Verifica colonne dataset
print("Colonne del dataset:")
covid_data.columns
# Out:
# Colonne del dataset:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
# Verifica dei metadati del dataset
print("Metadati del dataset:")
covid_data.info()
# Out:
# Metadati del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387330 entries, 0 to 387329
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    387330 non-null  object
#  1   continent                                   368774 non-null  object
#  2   location                                    387330 non-null  object
#  3   date                                        387330 non-null  object
#  4   total_cases                                 348333 non-null  float64
#  5   new_cases                                   376280 non-null  float64
#  6   new_cases_smoothed                          375050 non-null  float64
#  7   total_deaths                                326109 non-null  float64
#  8   new_deaths                                  376589 non-null  float64
#  9   new_deaths_smoothed                         375359 non-null  float64
#  10  total_cases_per_million                     348333 non-null  float64
#  11  new_cases_per_million                       376280 non-null  float64
#  12  new_cases_smoothed_per_million              375050 non-null  float64
#  13  total_deaths_per_million                    326109 non-null  float64
#  14  new_deaths_per_million                      376589 non-null  float64
#  15  new_deaths_smoothed_per_million             375359 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                38656 non-null   float64
#  18  icu_patients_per_million                    38656 non-null   float64
#  19  hosp_patients                               40194 non-null   float64
#  20  hosp_patients_per_million                   40194 non-null   float64
#  21  weekly_icu_admissions                       10691 non-null   float64
#  22  weekly_icu_admissions_per_million           10691 non-null   float64
#  23  weekly_hosp_admissions                      24171 non-null   float64
#  24  weekly_hosp_admissions_per_million          24171 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          83363 non-null   float64
#  35  people_vaccinated                           79239 non-null   float64
#  36  people_fully_vaccinated                     76123 non-null   float64
#  37  total_boosters                              51548 non-null   float64
#  38  new_vaccinations                            69093 non-null   float64
#  39  new_vaccinations_smoothed                   190100 non-null  float64
#  40  total_vaccinations_per_hundred              83363 non-null   float64
#  41  people_vaccinated_per_hundred               79239 non-null   float64
#  42  people_fully_vaccinated_per_hundred         76123 non-null   float64
#  43  total_boosters_per_hundred                  51548 non-null   float64
#  44  new_vaccinations_smoothed_per_million       190100 non-null  float64
#  45  new_people_vaccinated_smoothed              187453 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  187453 non-null  float64
#  47  stringency_index                            197292 non-null  float64
#  48  population_density                          329303 non-null  float64
#  49  median_age                                  306108 non-null  float64
#  50  aged_65_older                               295555 non-null  float64
#  51  aged_70_older                               303040 non-null  float64
#  52  gdp_per_capita                              300145 non-null  float64
#  53  extreme_poverty                             193483 non-null  float64
#  54  cardiovasc_death_rate                       300731 non-null  float64
#  55  diabetes_prevalence                         316236 non-null  float64
#  56  female_smokers                              225751 non-null  float64
#  57  male_smokers                                222683 non-null  float64
#  58  handwashing_facilities                      147332 non-null  float64
#  59  hospital_beds_per_thousand                  265635 non-null  float64
#  60  life_expectancy                             356730 non-null  float64
#  61  human_development_index                     291692 non-null  float64
#  62  population                                  387330 non-null  float64
#  63  excess_mortality_cumulative_absolute        13187 non-null   float64
#  64  excess_mortality_cumulative                 13187 non-null   float64
#  65  excess_mortality                            13187 non-null   float64
#  66  excess_mortality_cumulative_per_million     13187 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 198.0+ MB

# %%
# Controllo descrittori statistici di base
print("Descrittori statistici di base:")
covid_data.describe()
# Out:
# Descrittori statistici di base:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.483330e+05  3.762800e+05        3.750500e+05  3.261090e+05
# mean   7.386532e+06  8.728781e+03        8.756916e+03  8.996469e+04
# std    4.398509e+07  2.397048e+05        9.038526e+04  4.566992e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    9.448000e+03  0.000000e+00        0.000000e+00  1.360000e+02
# 50%    7.971300e+04  0.000000e+00        1.700000e+01  1.393000e+03
# 75%    8.516680e+05  0.000000e+00        4.024290e+02  1.257300e+04
# max    7.749544e+08  4.423623e+07        6.319461e+06  7.040264e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  376589.000000        375359.000000            348333.000000
# mean       78.157939            78.405166            112347.967657
# std      1424.517554           534.387547            160036.519608
# min         0.000000             0.000000                 0.000000
# 25%         0.000000             0.000000              2954.509000
# 50%         0.000000             0.143000             32240.542000
# 75%         0.000000             4.000000            155233.877000
# max    103719.000000         14817.000000            765370.756000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          376280.000000                   375050.000000
# mean              132.572340                      133.002194
# std              1544.311765                      571.529927
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.000000
# 50%                 0.000000                        4.197000
# 75%                 0.000000                       68.598000
# max            240325.866000                    34332.267000
#
#        total_deaths_per_million  ...   male_smokers  handwashing_facilities  \
# count             326109.000000  ...  222683.000000           147332.000000
# mean                 918.307054  ...      32.910922               50.793168
# std                 1131.569486  ...      13.572648               31.952844
# min                    0.000000  ...       7.700000                1.188000
# 25%                   65.307000  ...      22.600000               20.859000
# 50%                  414.035000  ...      33.100000               49.839000
# 75%                 1453.121000  ...      41.300000               82.686750
# max                 6485.570000  ...      78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               265635.000000    356730.000000            291692.000000
# mean                     3.097544        73.712526                 0.722586
# std                      2.548154         7.394828                 0.149001
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.590000                 0.602000
# 50%                      2.500000        75.050000                 0.740000
# 75%                      4.200000        79.460000                 0.829000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  3.873300e+05                          1.318700e+04
# mean   1.292804e+08                          5.579910e+04
# std    6.634103e+08                          1.559496e+05
# min    4.700000e+01                         -3.772610e+04
# 25%    4.490020e+05                          1.781000e+02
# 50%    5.882259e+06                          6.694300e+03
# 75%    2.830170e+07                          3.877775e+04
# max    7.975105e+09                          1.345330e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                 13187.000000      13187.000000
# mean                      9.770265         10.979027
# std                      12.022926         24.585788
# min                     -44.230000        -95.920000
# 25%                       2.080000         -1.490000
# 50%                       8.150000          5.660000
# 75%                      15.050000         15.690000
# max                      78.080000        377.830000
#
#        excess_mortality_cumulative_per_million
# count                             13187.000000
# mean                               1777.206419
# std                                1992.786873
# min                               -2936.453100
# 25%                                 120.205410
# 50%                                1248.656900
# 75%                                2878.521250
# max                               10293.515000
#
# [8 rows x 62 columns]

# %%
# Iteriamo ogni colonna del DataFrame
for column in covid_data.columns:
    # Verifichiamo se tipo categorico
    if covid_data[column].dtype=="object":
        print(f"{column} column contains categorical data.")
        # Conteggio valori unici
        unique_count = covid_data[column].nunique()
        print(f"{column} contains {unique_count} unique values")
        # Frequenza di ogni valore unico
        all_count = covid_data[column].value_counts()
        print(f"Distribution of every unique value is as such:")
        print(all_count)
        print()
# Out:
# iso_code column contains categorical data.
# iso_code contains 255 unique values
# Distribution of every unique value is as such:
# iso_code
# MYS         1551
# OWID_NAM    1551
# CZE         1551
# CAN         1551
# OWID_HIC    1551
#             ...
# OWID_SCT    1305
# OWID_WLS    1198
# MAC          795
# OWID_CYN     691
# ESH            1
# Name: count, Length: 255, dtype: int64
#
# continent column contains categorical data.
# continent contains 6 unique values
# Distribution of every unique value is as such:
# continent
# Africa           87439
# Europe           83590
# Asia             76499
# North America    62938
# Oceania          36828
# South America    21480
# Name: count, dtype: int64
#
# location column contains categorical data.
# location contains 255 unique values
# Distribution of every unique value is as such:
# location
# Malaysia           1551
# North America      1551
# Czechia            1551
# Canada             1551
# High income        1551
#                    ...
# Scotland           1305
# Wales              1198
# Macao               795
# Northern Cyprus     691
# Western Sahara        1
# Name: count, Length: 255, dtype: int64
#
# date column contains categorical data.
# date contains 1555 unique values
# Distribution of every unique value is as such:
# date
# 2022-04-20    255
# 2021-12-20    254
# 2021-12-06    254
# 2021-12-07    254
# 2021-12-08    254
#              ...
# 2024-04-03     17
# 2020-01-04      3
# 2020-01-03      2
# 2020-01-02      2
# 2020-01-01      2
# Name: count, Length: 1555, dtype: int64
#
# tests_units column contains categorical data.
# tests_units contains 4 unique values
# Distribution of every unique value is as such:
# tests_units
# tests performed    80099
# people tested      16257
# samples tested      9591
# units unclear        841
# Name: count, dtype: int64

# %%
# Iteriamo ogni colonna del DataFrame
for column in covid_data.columns:
    # Somma valori nulli
    nan_count = covid_data[column].isna().sum()
    # Calcolo della percentuale
    nan_percentage = round((nan_count/covid_data.shape[0])*100, 2)
    print(f"{column} contains {nan_count} NaN values, {nan_percentage}% of all rows.")
# Out:
# iso_code contains 0 NaN values, 0.0% of all rows.
# continent contains 18556 NaN values, 4.79% of all rows.
# location contains 0 NaN values, 0.0% of all rows.
# date contains 0 NaN values, 0.0% of all rows.
# total_cases contains 38997 NaN values, 10.07% of all rows.
# new_cases contains 11050 NaN values, 2.85% of all rows.
# new_cases_smoothed contains 12280 NaN values, 3.17% of all rows.
# total_deaths contains 61221 NaN values, 15.81% of all rows.
# new_deaths contains 10741 NaN values, 2.77% of all rows.
# new_deaths_smoothed contains 11971 NaN values, 3.09% of all rows.
# total_cases_per_million contains 38997 NaN values, 10.07% of all rows.
# new_cases_per_million contains 11050 NaN values, 2.85% of all rows.
# new_cases_smoothed_per_million contains 12280 NaN values, 3.17% of all rows.
# total_deaths_per_million contains 61221 NaN values, 15.81% of all rows.
# new_deaths_per_million contains 10741 NaN values, 2.77% of all rows.
# new_deaths_smoothed_per_million contains 11971 NaN values, 3.09% of all rows.
# reproduction_rate contains 202513 NaN values, 52.28% of all rows.
# icu_patients contains 348674 NaN values, 90.02% of all rows.
# icu_patients_per_million contains 348674 NaN values, 90.02% of all rows.
# hosp_patients contains 347136 NaN values, 89.62% of all rows.
# hosp_patients_per_million contains 347136 NaN values, 89.62% of all rows.
# weekly_icu_admissions contains 376639 NaN values, 97.24% of all rows.
# weekly_icu_admissions_per_million contains 376639 NaN values, 97.24% of all rows.
# weekly_hosp_admissions contains 363159 NaN values, 93.76% of all rows.
# weekly_hosp_admissions_per_million contains 363159 NaN values, 93.76% of all rows.
# total_tests contains 307943 NaN values, 79.5% of all rows.
# new_tests contains 311927 NaN values, 80.53% of all rows.
# total_tests_per_thousand contains 307943 NaN values, 79.5% of all rows.
# new_tests_per_thousand contains 311927 NaN values, 80.53% of all rows.
# new_tests_smoothed contains 283365 NaN values, 73.16% of all rows.
# new_tests_smoothed_per_thousand contains 283365 NaN values, 73.16% of all rows.
# positive_rate contains 291403 NaN values, 75.23% of all rows.
# tests_per_case contains 292982 NaN values, 75.64% of all rows.
# tests_units contains 280542 NaN values, 72.43% of all rows.
# total_vaccinations contains 303967 NaN values, 78.48% of all rows.
# people_vaccinated contains 308091 NaN values, 79.54% of all rows.
# people_fully_vaccinated contains 311207 NaN values, 80.35% of all rows.
# total_boosters contains 335782 NaN values, 86.69% of all rows.
# new_vaccinations contains 318237 NaN values, 82.16% of all rows.
# new_vaccinations_smoothed contains 197230 NaN values, 50.92% of all rows.
# total_vaccinations_per_hundred contains 303967 NaN values, 78.48% of all rows.
# people_vaccinated_per_hundred contains 308091 NaN values, 79.54% of all rows.
# people_fully_vaccinated_per_hundred contains 311207 NaN values, 80.35% of all rows.
# total_boosters_per_hundred contains 335782 NaN values, 86.69% of all rows.
# new_vaccinations_smoothed_per_million contains 197230 NaN values, 50.92% of all rows.
# new_people_vaccinated_smoothed contains 199877 NaN values, 51.6% of all rows.
# new_people_vaccinated_smoothed_per_hundred contains 199877 NaN values, 51.6% of all rows.
# stringency_index contains 190038 NaN values, 49.06% of all rows.
# population_density contains 58027 NaN values, 14.98% of all rows.
# median_age contains 81222 NaN values, 20.97% of all rows.
# aged_65_older contains 91775 NaN values, 23.69% of all rows.
# aged_70_older contains 84290 NaN values, 21.76% of all rows.
# gdp_per_capita contains 87185 NaN values, 22.51% of all rows.
# extreme_poverty contains 193847 NaN values, 50.05% of all rows.
# cardiovasc_death_rate contains 86599 NaN values, 22.36% of all rows.
# diabetes_prevalence contains 71094 NaN values, 18.35% of all rows.
# female_smokers contains 161579 NaN values, 41.72% of all rows.
# male_smokers contains 164647 NaN values, 42.51% of all rows.
# handwashing_facilities contains 239998 NaN values, 61.96% of all rows.
# hospital_beds_per_thousand contains 121695 NaN values, 31.42% of all rows.
# life_expectancy contains 30600 NaN values, 7.9% of all rows.
# human_development_index contains 95638 NaN values, 24.69% of all rows.
# population contains 0 NaN values, 0.0% of all rows.
# excess_mortality_cumulative_absolute contains 374143 NaN values, 96.6% of all rows.
# excess_mortality_cumulative contains 374143 NaN values, 96.6% of all rows.
# excess_mortality contains 374143 NaN values, 96.6% of all rows.
# excess_mortality_cumulative_per_million contains 374143 NaN values, 96.6% of all rows.

# %%
#Elimino dati nulli dalla colonna continent
continent_df = covid_data.dropna(subset=['continent'])
    
#Calcolo il valore max per ogni location, essendo il total_cases un valore comulativo
max_cases_per_continent = continent_df.groupby(['continent', 'location'])['total_cases'].max()
    
#Somma dei max di ogni location per ottenere il totale
total_cases = max_cases_per_continent.groupby(level='continent').sum()
    
total_cases.to_frame()
# Out:
#                total_cases
# continent
# Africa          13139991.0
# Asia           301414628.0
# Europe         252376812.0
# North America  124530611.0
# Oceania         14808141.0
# South America   68716854.0

# %%
import humanize

# Calcolo dei descrittori statistici per i due continenti
df_europe = continent_df[continent_df['continent'] == 'Europe']
df_asia = continent_df[continent_df['continent'] == 'Asia']

# Valore massimo per Europa
max_europe = df_europe.groupby('location')['total_cases'].max().sum()
formatted_max_europe = humanize.intword(max_europe)
print("Valore massimo per Europa:")
formatted_max_europe
# Out:
# Valore massimo per Europa:
# '252.4 million'

# %%
# Valore massimo per Asia
max_asia = df_asia.groupby('location')['total_cases'].max().sum()
formatted_max_asia = humanize.intword(max_asia)
print("Valore massimo per Asia:")
formatted_max_asia
# Out:
# Valore massimo per Asia:
# '301.4 million'

# %%
# Media per Europa
mean_europe = df_europe['total_cases'].mean()
formatted_mean_europe = humanize.intword(mean_europe)
print("Media per Europa:")
formatted_mean_europe
# Out:
# Media per Europa:
# '2.7 million'

# %%
# Media per Asia
mean_asia = df_asia['total_cases'].mean()
formatted_mean_asia = humanize.intword(mean_asia)
print("Media per Asia:")
formatted_mean_asia
# Out:
# Media per Asia:
# '3.2 million'

# %%
# Calcolo numero totale di casi nel mondo
total_world_cases = covid_data['new_cases'].sum()
formatted_total_world_cases = humanize.intword(total_world_cases)
print("Numero totale di casi nel mondo:")
formatted_total_world_cases
# Out:
# Numero totale di casi nel mondo:
# '3.3 billion'

# %%
# Percentuale rispetto al numero totale di casi nel mondo Europa
percentage_europe = (df_europe['new_cases'].sum() / total_world_cases) * 100
print("Percentuale rispetto al numero totale di casi nel mondo Europa:")
percentage_europe
# Out:
# Percentuale rispetto al numero totale di casi nel mondo Europa:
# 7.683953566625948

# %%
# Percentuale rispetto al numero totale di casi nel mondo Asia
percentage_asia = (df_asia['new_cases'].sum() / total_world_cases) * 100
print("Percentuale rispetto al numero totale di casi nel mondo continente Asia:")
percentage_asia
# Out:
# Percentuale rispetto al numero totale di casi nel mondo continente Asia:
# 9.177945433226723

# %%
# Converisone colonna 'date' in formato datetime
covid_data['date'] = pd.to_datetime(covid_data['date'])

# Filtro dati per l'Italia nel 2022
italy_data_2022 = covid_data[(covid_data['location'] == 'Italy') & (covid_data['date'].dt.year == 2022)]

# Visualizzazione prime 5 righe per controllo del dataframe filtrato
italy_data_2022.head()
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 166403      ITA    Europe    Italy 2022-01-01    5622431.0        0.0
# 166404      ITA    Europe    Italy 2022-01-02    6267035.0   644604.0
# 166405      ITA    Europe    Italy 2022-01-03    6267035.0        0.0
# 166406      ITA    Europe    Italy 2022-01-04    6267035.0        0.0
# 166407      ITA    Europe    Italy 2022-01-05    6267035.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 166403           36797.000      136530.0         0.0              140.857
# 166404           92086.286      137513.0       983.0              140.429
# 166405           92086.286      137513.0         0.0              140.429
# 166406           92086.286      137513.0         0.0              140.429
# 166407           92086.286      137513.0         0.0              140.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 166403  ...          27.8                     NaN                        3.18
# 166404  ...          27.8                     NaN                        3.18
# 166405  ...          27.8                     NaN                        3.18
# 166406  ...          27.8                     NaN                        3.18
# 166407  ...          27.8                     NaN                        3.18
#
#         life_expectancy  human_development_index  population  \
# 166403            83.51                    0.892  59037472.0
# 166404            83.51                    0.892  59037472.0
# 166405            83.51                    0.892  59037472.0
# 166406            83.51                    0.892  59037472.0
# 166407            83.51                    0.892  59037472.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 166403                                   NaN                          NaN
# 166404                              168226.3                        12.99
# 166405                                   NaN                          NaN
# 166406                                   NaN                          NaN
# 166407                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 166403               NaN                                      NaN
# 166404              8.06                                2849.4834
# 166405               NaN                                      NaN
# 166406               NaN                                      NaN
# 166407               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
# Generazione grafico con metodo plot
italy_data_2022.plot(x='date', y='total_cases', figsize=(10, 6), title ='Evoluzione dei casi totali in Italia nel 2022', xlabel='Data', ylabel='Casi Totali')
# Out:
# <Axes: title={'center': 'Evoluzione dei casi totali in Italia nel 2022'}, xlabel='Data', ylabel='Casi Totali'>

# %%
# Generazione grafico con metodo plot
italy_data_2022.plot(x='date', y='new_cases', figsize=(10, 6), title ='Numero di nuovi casi in Italia nel 2022', xlabel='Data', ylabel='Nuovi Casi Giornalieri')
# Out:
# <Axes: title={'center': 'Numero di nuovi casi in Italia nel 2022'}, xlabel='Data', ylabel='Nuovi Casi Giornalieri'>

# %%
# Calcolo della somma cumulativa dei nuovi casi giornalieri
italy_data_2022.loc[:, 'cumulative_new_cases'] = italy_data_2022['new_cases'].cumsum()

# %%
# Generazione del grafico con Matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
italy_data_2022.plot(x='date', y='cumulative_new_cases', marker='o', linestyle='-', figsize=(10, 6))
plt.title('Numero cumulativo dei nuovi casi in Italia nel 2022')
plt.xlabel('Data')
plt.ylabel('Numero cumulativo dei nuovi casi')
plt.grid(True)
plt.xticks(rotation=45)

# Commento
plt.text(0.5, -0.3, "Il grafico della somma cumulativa dei nuovi casi del 2022 in Italia riflette in gran parte l'andamento dei casi totali nel periodo. Questo mi fa capire che i numeri in total_cases erano appunto progressivi / cumulativi", transform=plt.gca().transAxes, ha='center', fontsize=10,wrap=True) 
plt.show()

# %%
import seaborn as sns

selected_countries = ['Italy', 'Germany', 'France']
start_date = '2022-05-01'
end_date = '2023-04-30'

# Filtro dati per le nazioni specificate nel periodo specificato
filtered_data = covid_data[((covid_data[ 'location' ] == 'Italy') |
                           (covid_data[ 'location' ] == 'Germany') |
                           (covid_data[ 'location' ] == 'France')) &
                           ((covid_data[ 'date' ] >= start_date) &
                           (covid_data[ 'date' ] <= end_date))]

# Controllo del dataframe filtrato
filtered_data
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 117406      FRA    Europe   France 2022-05-01   27742592.0   376510.0
# 117407      FRA    Europe   France 2022-05-02   27742592.0        0.0
# 117408      FRA    Europe   France 2022-05-03   27742592.0        0.0
# 117409      FRA    Europe   France 2022-05-04   27742592.0        0.0
# 117410      FRA    Europe   France 2022-05-05   27742592.0        0.0
# ...         ...       ...      ...        ...          ...        ...
# 166883      ITA    Europe    Italy 2023-04-26   25772459.0        0.0
# 166884      ITA    Europe    Italy 2023-04-27   25772459.0        0.0
# 166885      ITA    Europe    Italy 2023-04-28   25772459.0        0.0
# 166886      ITA    Europe    Italy 2023-04-29   25772459.0        0.0
# 166887      ITA    Europe    Italy 2023-04-30   25795509.0    23050.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 117406           53787.143      146744.0       867.0              123.857
# 117407           53787.143      146744.0         0.0              123.857
# 117408           53787.143      146744.0         0.0              123.857
# 117409           53787.143      146744.0         0.0              123.857
# 117410           53787.143      146744.0         0.0              123.857
# ...                    ...           ...         ...                  ...
# 166883            3808.429      189627.0         0.0               26.714
# 166884            3808.429      189627.0         0.0               26.714
# 166885            3808.429      189627.0         0.0               26.714
# 166886            3808.429      189627.0         0.0               26.714
# 166887            3292.857      189786.0       159.0               22.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 117406  ...          35.6                     NaN                        5.98
# 117407  ...          35.6                     NaN                        5.98
# 117408  ...          35.6                     NaN                        5.98
# 117409  ...          35.6                     NaN                        5.98
# 117410  ...          35.6                     NaN                        5.98
# ...     ...           ...                     ...                         ...
# 166883  ...          27.8                     NaN                        3.18
# 166884  ...          27.8                     NaN                        3.18
# 166885  ...          27.8                     NaN                        3.18
# 166886  ...          27.8                     NaN                        3.18
# 166887  ...          27.8                     NaN                        3.18
#
#         life_expectancy  human_development_index  population  \
# 117406            82.66                    0.901  67813000.0
# 117407            82.66                    0.901  67813000.0
# 117408            82.66                    0.901  67813000.0
# 117409            82.66                    0.901  67813000.0
# 117410            82.66                    0.901  67813000.0
# ...                 ...                      ...         ...
# 166883            83.51                    0.892  59037472.0
# 166884            83.51                    0.892  59037472.0
# 166885            83.51                    0.892  59037472.0
# 166886            83.51                    0.892  59037472.0
# 166887            83.51                    0.892  59037472.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 117406                              89517.72                         6.19
# 117407                                   NaN                          NaN
# 117408                                   NaN                          NaN
# 117409                                   NaN                          NaN
# 117410                                   NaN                          NaN
# ...                                      ...                          ...
# 166883                                   NaN                          NaN
# 166884                                   NaN                          NaN
# 166885                                   NaN                          NaN
# 166886                                   NaN                          NaN
# 166887                             241766.50                        11.16
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 117406              6.24                                1385.1523
# 117407               NaN                                      NaN
# 117408               NaN                                      NaN
# 117409               NaN                                      NaN
# 117410               NaN                                      NaN
# ...                  ...                                      ...
# 166883               NaN                                      NaN
# 166884               NaN                                      NaN
# 166885               NaN                                      NaN
# 166886               NaN                                      NaN
# 166887              3.09                                4106.7330
#
# [1095 rows x 67 columns]

# %%
# Controllo esito somme
icu_patients_per_country = filtered_data.groupby( 'location' )['icu_patients'].sum()
print("Pazienti in terapia intensiva per nazione:")
icu_patients_per_country
# Out:
# Pazienti in terapia intensiva per nazione:
# location
# France     334457.0
# Germany    373171.0
# Italy       84408.0
# Name: icu_patients, dtype: float64

# %%
# Generazione del boxplot con Seaborn
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='location',y='icu_patients_per_million', data=filtered_data)
plt.title('Differenza nel numero di pazienti in terapia intensiva tra Italia, Germania e Francia (Maggio 2022 - Aprile 2023)')
plt.xlabel('Nazione')
plt.ylabel('Numero di pazienti in terapia intensiva')
plt.show()

# %%
year = '2023'

# Filtro dati per le nazioni specificate nell'anno 2023
filtered_data_2023 = covid_data[((covid_data[ 'location' ] == 'Italy') |
                           (covid_data[ 'location' ] == 'Germany') |
                           (covid_data[ 'location' ] == 'France') |
                           (covid_data[ 'location' ] == 'Spain')) &
                           (covid_data['date'].dt.year == 2023)]

# Controllo del dataframe filtrato
filtered_data_2023_2 = filtered_data_2023[['location', 'date', 'hosp_patients_per_million']]
filtered_data_2023_2.sample(5)
# Out:
#        location       date  hosp_patients_per_million
# 117929   France 2023-10-06                        NaN
# 327520    Spain 2023-01-01                     69.409
# 166891    Italy 2023-05-04                     49.460
# 127112  Germany 2023-09-15                        NaN
# 167047    Italy 2023-10-07                     58.421

# %%
# Calcolo della somma dei pazienti ospitalizzati per ciascuna nazione
hospitalized_sum_per_country = filtered_data_2023.groupby( 'location' )['hosp_patients_per_million'].sum()  
print("Pazienti ospitalizzati per nazione:")
hospitalized_sum_per_country
# Out:
# Pazienti ospitalizzati per nazione:
# location
# France     20388.040
# Germany        0.000
# Italy      19907.221
# Spain       7456.112
# Name: hosp_patients_per_million, dtype: float64

# %%
# Iteriamo ogni colonna del DataFrame
for column in filtered_data_2023_2.columns:
    # Somma valori nulli
    nan_count = filtered_data_2023_2[column].isna().sum()
    # Calcolo della percentuale
    nan_percentage = round((nan_count/filtered_data_2023_2.shape[0])*100, 2)
    print(f"{column} contains {nan_count} NaN values, {nan_percentage}% of all rows.")
# Out:
# location contains 0 NaN values, 0.0% of all rows.
# date contains 0 NaN values, 0.0% of all rows.
# hosp_patients_per_million contains 843 NaN values, 57.74% of all rows.

# %%
print("Vista la quantita dei dati nulli, e il fatto che non abbiamo alcun dato per la Germania, non possiamo semplicemente eliminare le righe. Potremmo scegliere di riempire i vuoti per le nazioni diverse da Germania con una media calcolata sul numero precedente e numero immediatamente seguente. Per la Germania, consiglierei se possibile di recuperare i dati mancanti da altre fonti di modo da generare un dataset completo.")
# Out:
# Vista la quantita dei dati nulli, e il fatto che non abbiamo alcun dato per la Germania, non possiamo semplicemente eliminare le righe. Potremmo scegliere di riempire i vuoti per le nazioni diverse da Germania con una media calcolata sul numero precedente e numero immediatamente seguente. Per la Germania, consiglierei se possibile di recuperare i dati mancanti da altre fonti di modo da generare un dataset completo.
